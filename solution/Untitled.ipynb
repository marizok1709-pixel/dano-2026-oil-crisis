# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Настройка, чтобы графики отображались прямо в ноутбуке
# %matplotlib inline

# Чтение CSV-файла
df = pd.read_csv('имя_вашего_файла.csv')

# Посмотреть первые 5 строк данных, чтобы проверить структуру
df.head()
